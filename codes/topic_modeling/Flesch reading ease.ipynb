# %%
import textstat

# %%
import pandas as pd
import re
import numpy as np
import re
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import scipy.stats as stats
import pandas as pd
import urllib
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# #전처리 필요성??,,
# preprocessed_data = []
#
#
# emoji_pattern = re.compile("["
#         u"\U0001F600-\U0001F64F"  # emoticons
#         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#         u"\U0001F680-\U0001F6FF"  # transport & map symbols
#         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                            "]+", flags=re.UNICODE)
#
# for i in content_lists:
#     final_text = emoji_pattern.sub(r'', i)
#     final_text = re.sub('[-=.#/?:$}]', '', final_text)
#     preprocessed_data.append(final_text)

# %%
def get_level(df):
    result = []
    if(df['score'] >=90):
        return ('Very Easy')
    elif(df['score'] >= 80):
        return ("Easy")
    elif(df['score'] >= 70):
        return ("Fairly Easy") 
    elif(df['score'] >= 60):
        return ("Standard")
    elif(df['score'] >= 50):
        return ("Fairly Difficult")
    elif(df['score'] >= 30):
        return ("Difficult")
    else:
        return("Very Confusing")

# %% [markdown]
# # ADHD

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\adhd\\adhd_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_context']):
    content_lists.append(i)

# %%
count = 0
adhd_result = []
for i in content_lists:
    count += 1
    adhd_result.append(textstat.flesch_reading_ease(i))

# %%
adhd_readability = pd.DataFrame({"score":adhd_result})

# %%
adhd_readability['level'] = adhd_readability.apply(get_level, axis = 1)

# %%
adhd_readability
# Out:
#       score             level
# 0     56.73  Fairly Difficult
# 1   -156.90    Very Confusing
# 2     64.38          Standard
# 3     67.42          Standard
# 4     64.88          Standard
# ..      ...               ...
# 995   39.54         Difficult
# 996   81.26              Easy
# 997   90.19         Very Easy
# 998   60.89          Standard
# 999   72.50       Fairly Easy
#
# [1000 rows x 2 columns]

# %%
sns.distplot(adhd_readability['score'],  hist_kws=dict(ec='w'), label='non smoker');

# %%
sns.countplot(adhd_readability['level'])

# %%
adhd_readability_count = adhd_readability['level'].value_counts()
adhd_readability_count
# Out:
# Fairly Easy         243
# Standard            235
# Fairly Difficult    162
# Difficult           137
# Very Confusing      109
# Easy                 96
# Very Easy            18
# Name: level, dtype: int64

# %% [markdown]
# # Anxiety

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\anxiety\\anxiety_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_context']):
    content_lists.append(i)

# %%
count = 0
anxiety_result = []
for i in content_lists:
    count += 1
    anxiety_result.append(textstat.flesch_reading_ease(i))

# %%
anxiety_readability = pd.DataFrame({"score":anxiety_result})

# %%
anxiety_readability['level'] = anxiety_readability.apply(get_level, axis = 1)

# %%
anxiety_readability
# Out:
#      score             level
# 0    59.23  Fairly Difficult
# 1    10.24    Very Confusing
# 2    87.42              Easy
# 3    67.32          Standard
# 4    79.70       Fairly Easy
# ..     ...               ...
# 995  29.56    Very Confusing
# 996  71.48       Fairly Easy
# 997  50.50  Fairly Difficult
# 998  72.02       Fairly Easy
# 999  37.64         Difficult
#
# [1000 rows x 2 columns]

# %%
sns.distplot(anxiety_result,  hist_kws=dict(ec='w'), label='non smoker');

# %%
sns.countplot(anxiety_readability['level'])

# %%
anxiety_readability_count = anxiety_readability['level'].value_counts()
anxiety_readability_count
# Out:
# Fairly Easy         268
# Standard            253
# Easy                130
# Fairly Difficult    126
# Difficult           111
# Very Confusing       86
# Very Easy            26
# Name: level, dtype: int64

# %% [markdown]
# # Schizophrenia

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\schizo\\schizo_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_context']):
    content_lists.append(i)

# %%
count = 0
schizo_result = []
for i in content_lists:
    count += 1
    schizo_result.append(textstat.flesch_reading_ease(i))

# %%
schizo_readability = pd.DataFrame({"score":schizo_result})

# %%
schizo_readability['level'] = schizo_readability.apply(get_level, axis = 1)

# %%
schizo_readability
# Out:
#       score             level
# 0     69.28          Standard
# 1   -200.89    Very Confusing
# 2     55.07  Fairly Difficult
# 3     63.70          Standard
# 4     50.16  Fairly Difficult
# ..      ...               ...
# 995   92.73         Very Easy
# 996   44.91         Difficult
# 997   17.54    Very Confusing
# 998   71.99       Fairly Easy
# 999   24.30    Very Confusing
#
# [1000 rows x 2 columns]

# %%
sns.distplot(schizo_result,  hist_kws=dict(ec='w'), label='non smoker');

# %%
sns.countplot(schizo_readability['level'])

# %%
schizo_readability_count = schizo_readability['level'].value_counts()
schizo_readability_count
# Out:
# Fairly Easy         254
# Standard            197
# Easy                151
# Very Confusing      125
# Fairly Difficult    119
# Difficult           109
# Very Easy            45
# Name: level, dtype: int64

# %% [markdown]
# # Bipolar

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\bipolar\\bipolar_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_context']):
    content_lists.append(i)

# %%
count = 0
bipolar_result = []
for i in content_lists:
    count += 1
    bipolar_result.append(textstat.flesch_reading_ease(i))

# %%
bipolar_readability = pd.DataFrame({"score":bipolar_result})

# %%
bipolar_readability['level'] = bipolar_readability.apply(get_level, axis = 1)

# %%
bipolar_readability
# Out:
#      score           level
# 0    77.27     Fairly Easy
# 1    67.12        Standard
# 2    44.07       Difficult
# 3    75.34     Fairly Easy
# 4    65.12        Standard
# ..     ...             ...
# 995  76.56     Fairly Easy
# 996 -11.76  Very Confusing
# 997  72.50     Fairly Easy
# 998  81.63            Easy
# 999  83.25            Easy
#
# [1000 rows x 2 columns]

# %%
sns.distplot(bipolar_result,  hist_kws=dict(ec='w'));

# %%
sns.countplot(bipolar_readability['level'])

# %%
bipolar_readability_count = bipolar_readability['level'].value_counts()
bipolar_readability_count
# Out:
# Fairly Easy         245
# Standard            226
# Easy                170
# Fairly Difficult    130
# Very Confusing       90
# Difficult            89
# Very Easy            50
# Name: level, dtype: int64

# %% [markdown]
# # Depression

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\depression\\depression_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_content']):
    content_lists.append(i)

# %%
count = 0
depression_result = []
for i in content_lists:
    count += 1
    depression_result.append(textstat.flesch_reading_ease(i))

# %%
depression_readability = pd.DataFrame({"score":depression_result})

# %%
depression_readability['level'] = depression_readability.apply(get_level, axis = 1)

# %%
depression_readability
# Out:
#      score             level
# 0    88.97              Easy
# 1    69.15          Standard
# 2    56.59  Fairly Difficult
# 3    59.30  Fairly Difficult
# 4    83.66              Easy
# ..     ...               ...
# 995  85.49              Easy
# 996  75.95       Fairly Easy
# 997  84.00              Easy
# 998  77.61       Fairly Easy
# 999  81.73              Easy
#
# [1000 rows x 2 columns]

# %%
sns.distplot(depression_result,  hist_kws=dict(ec='w'));

# %%
sns.countplot(depression_readability['level'])

# %%
depression_readability_count = depression_readability['level'].value_counts()
depression_readability_count
# Out:
# Fairly Easy         246
# Easy                233
# Standard            191
# Very Easy           102
# Very Confusing       85
# Difficult            72
# Fairly Difficult     71
# Name: level, dtype: int64

# %% [markdown]
# # non-mental_health

# %%
df = pd.read_csv("D:\\2020-2\\소프트웨어융합캡스톤디자인\\jupyter\\data\\health\\non_mental_health_sanity_1000.csv")

# %%
content_lists = []
for i in (df['title'] + df['text_context']):
    content_lists.append(i)

# %%
count = 0
non_mental_health_result = []
for i in content_lists:
    count += 1
    non_mental_health_result.append(textstat.flesch_reading_ease(i))

# %%
non_mental_health_readability = pd.DataFrame({"score":non_mental_health_result})

# %%
non_mental_health_readability['level'] = non_mental_health_readability.apply(get_level, axis = 1)

# %%
non_mental_health_readability
# Out:
#       score             level
# 0     82.07              Easy
# 1     57.27  Fairly Difficult
# 2     83.56              Easy
# 3     75.44       Fairly Easy
# 4     69.86          Standard
# ...     ...               ...
# 997   67.08          Standard
# 998   80.28              Easy
# 999   57.81  Fairly Difficult
# 1000  77.81       Fairly Easy
# 1001  70.13       Fairly Easy
#
# [1002 rows x 2 columns]

# %%
sns.distplot(non_mental_health_result,   hist_kws=dict(ec='w'));

# %%
plt.xticks(rotation = - 45 )
sns.countplot(non_mental_health_readability['level'])

# %%
non_mental_health_readability_count = non_mental_health_readability['level'].value_counts()
count
# Out:
# 1002

# %%
non_mental_health_readability_count['Fairly Easy']
# Out:
# 276

# %% [markdown]
# # ANOVA

# %%
F_statistic, pVal = stats.f_oneway(adhd_readability['score'], anxiety_readability['score'], schizo_readability['score'], bipolar_readability['score'], depression_readability['score'], non_mental_health_readability['score'])

print('Altman 910 데이터의 일원분산분석 결과 : F={0:.1f}, p={1:.5f}'.format(F_statistic, pVal))
if pVal < 0.05:
    print('P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.')
# Out:
# Altman 910 데이터의 일원분산분석 결과 : F=4.0, p=0.00127
# P-value 값이 충분히 작음으로 인해 그룹의 평균값이 통계적으로 유의미하게 차이납니다.

# %% [markdown]
# # 전체 비교_barplot

# %%
# Very Easy

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Very Easy'], anxiety_readability_count['Very Easy'], schizo_readability_count['Very Easy'], bipolar_readability_count['Very Easy'], depression_readability_count['Very Easy'], non_mental_health_readability_count['Very Easy']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Very Easy")
sns.barplot(subreddit, count);

# %%
#Easy

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Easy'], anxiety_readability_count['Easy'], schizo_readability_count['Easy'], bipolar_readability_count['Easy'], depression_readability_count['Easy'], non_mental_health_readability_count['Easy']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Easy")
sns.barplot(subreddit, count);

# %%
# Easy Fairly

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Fairly Easy'], anxiety_readability_count['Fairly Easy'], schizo_readability_count['Fairly Easy'], bipolar_readability_count['Fairly Easy'], depression_readability_count['Fairly Easy'], non_mental_health_readability_count['Fairly Easy']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Easy Fairly")
sns.barplot(subreddit, count);

# %%
# Standard

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Standard'], anxiety_readability_count['Standard'], schizo_readability_count['Standard'], bipolar_readability_count['Standard'], depression_readability_count['Standard'], non_mental_health_readability_count['Standard']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Standard")
sns.barplot(subreddit, count);

# %%
# Fairly Difficult

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Fairly Difficult'], anxiety_readability_count['Fairly Difficult'], schizo_readability_count['Fairly Difficult'], bipolar_readability_count['Fairly Difficult'], depression_readability_count['Fairly Difficult'], non_mental_health_readability_count['Fairly Difficult']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Fairly Difficult")
sns.barplot(subreddit, count);

# %%
# Difficult

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Difficult'], anxiety_readability_count['Difficult'], schizo_readability_count['Difficult'], bipolar_readability_count['Difficult'], depression_readability_count['Difficult'], non_mental_health_readability_count['Difficult']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Difficult")
sns.barplot(subreddit, count);

# %%
# Very Confusing

subreddit = ['ADHD', 'Anxiety', 'Schizophrenia', 'Bipolar', 'Depression', 'non-mental']
count = [adhd_readability_count['Very Confusing'], anxiety_readability_count['Very Confusing'], schizo_readability_count['Very Confusing'], bipolar_readability_count['Very Confusing'], depression_readability_count['Very Confusing'], non_mental_health_readability_count['Very Confusing']]

plt.ylim(0, 280)
plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("number of post")
plt.title("Very Confusing")
sns.barplot(subreddit, count);

# %%
adhd_readability_count
# Out:
# Fairly Easy         243
# Standard            235
# Fairly Difficult    162
# Difficult           137
# Very Confusing      109
# Easy                 96
# Very Easy            18
# Name: level, dtype: int64

# %% [markdown]
# # 전체 비교_히스토그램

# %%
sns.distplot(adhd_result,hist_kws=dict(ec='w'), hist=False, label='ADHD');
sns.distplot(anxiety_result, hist_kws=dict(ec='w'), hist=False, label='Anxiety');
sns.distplot(schizo_result, hist_kws=dict(ec='w'), hist=False, label='Schizophrenia');
sns.distplot(bipolar_result, hist_kws=dict(ec='w'), hist=False, label='Bipolar');
sns.distplot(depression_result, hist_kws=dict(ec='w'), hist=False, label='Depression');
sns.distplot(non_mental_health_result, hist_kws=dict(ec='w'), hist=False, label='non_mental_health');


plt.xlim(0, 100)
plt.legend();

# %% [markdown]
# # 전체비교_boxplot

# %%
print(len(non_mental_health_result))
# Out:
# 1002

# %%
total = pd.DataFrame({"ADHD":adhd_result, "Anxiety": anxiety_result, "Schizophrenia": schizo_result, "Bipolar":bipolar_result, "Depression":depression_result, "non-mental":non_mental_health_result[:1000]})
total
# Out:
#        ADHD  Anxiety  Schizophrenia  Bipolar  Depression  non-mental
# 0     56.73    59.23          69.28    77.27       88.97       82.07
# 1   -156.90    10.24        -200.89    67.12       69.15       57.27
# 2     64.38    87.42          55.07    44.07       56.59       83.56
# 3     67.42    67.32          63.70    75.34       59.30       75.44
# 4     64.88    79.70          50.16    65.12       83.66       69.86
# ..      ...      ...            ...      ...         ...         ...
# 995   39.54    29.56          92.73    76.56       85.49       58.96
# 996   81.26    71.48          44.91   -11.76       75.95       60.65
# 997   90.19    50.50          17.54    72.50       84.00       67.08
# 998   60.89    72.02          71.99    81.63       77.61       80.28
# 999   72.50    37.64          24.30    83.25       81.73       57.81
#
# [1000 rows x 6 columns]

# %%
plt.figure(figsize=(5, 8))
plt.xlabel("subreddit")
plt.ylabel("score")
plt.ylim(-150, 130)
plt.xticks(rotation = - 45 )
sns.boxplot(data=total);

# %%
total2 = pd.DataFrame({"ADHD":adhd_readability_count, "Anxiety": anxiety_readability_count, "Schizophrenia": schizo_readability_count, "Bipolar":bipolar_readability_count, "Depression":depression_readability_count, "non-mental":non_mental_health_readability_count[:1000]})
total2 = total2.reindex(index = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Difficult", "Very Confusing"])
total2
# Out:
#                   ADHD  Anxiety  Schizophrenia  Bipolar  Depression  \
# Very Easy           18       26             45       50         102
# Easy                96      130            151      170         233
# Fairly Easy        243      268            254      245         246
# Standard           235      253            197      226         191
# Fairly Difficult   162      126            119      130          71
# Difficult          137      111            109       89          72
# Very Confusing     109       86            125       90          85
#
#                   non-mental
# Very Easy                 50
# Easy                     121
# Fairly Easy              276
# Standard                 208
# Fairly Difficult         136
# Difficult                 98
# Very Confusing           113

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.xlabel("subreddit")
plt.ylabel("score")
plt.plot(levels, total2["ADHD"],  marker='o', label='ADHD')
plt.plot(levels, total2["Anxiety"],  marker='o', label='Anxiety')
plt.plot(levels, total2["Schizophrenia"],   marker='o', label='Schizophrenia')
plt.plot(levels, total2["Bipolar"], marker='o', label='Bipolar')
plt.plot(levels, total2["Depression"],  marker='o', label='Depression')
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental')
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.title("ADHD")
plt.ylim(0, 290)
plt.plot(levels, total2["ADHD"],  marker='o', label='ADHD')
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.title("Anxiety")
plt.ylim(0, 290)
plt.plot(levels, total2["Anxiety"],  marker='o', label='Anxiety', color = "orange")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.title("Schizophrenia")
plt.ylim(0, 290)
plt.plot(levels, total2["Schizophrenia"],   marker='o', label='Schizophrenia', color ="green")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.title("Bipolar")
plt.ylim(0, 290)
plt.plot(levels, total2["Bipolar"], marker='o', label='Bipolar', color ="red")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.title("Depression")
plt.plot(levels, total2["Depression"],  marker='o', label='Depression', color = "purple")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.title("non-mental")
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.plot(levels, total2["ADHD"],  marker='o', label='ADHD')
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.plot(levels, total2["Anxiety"],  marker='o', label='Anxiety', color = "orange")
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.plot(levels, total2["Schizophrenia"],   marker='o', label='Schizophrenia', color ="green")
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.plot(levels, total2["Bipolar"], marker='o', label='Bipolar', color ="red")
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
levels = ["Very Easy", "Easy", "Fairly Easy", "Standard", "Fairly Difficult", "Diffult", "Very Confusing"]

plt.xticks(rotation = - 45 )
plt.ylim(0, 290)
plt.plot(levels, total2["Depression"],  marker='o', label='Depression', color = "purple")
plt.plot(levels, total2["non-mental"],   marker='o', label='non-mental', color = "brown")
plt.legend();

# %%
lists = [1,1,2,3,4]
aryy = np.array(lists)

# %%
plt.hist(lists, ec = 'w')
# Out:
# (array([2., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(lists, density = True, ec = 'w')
# Out:
# (array([1.33333333, 0.        , 0.        , 0.66666667, 0.        ,
#         0.        , 0.66666667, 0.        , 0.        , 0.66666667]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
lists = [1,1,2,3,4]
aryy = np.array(lists)
binss = np.arange(1,4,1)

# %%
plt.hist(aryy, bins = binss , density= True)
# Out:
# (array([0.5, 0.5]), array([1, 2, 3]), <a list of 2 Patch objects>)

# %%
lists = [1,1,2,3]
x = np.array(lists)
y = (1 / np.sqrt(2 * np.pi)) * np.exp(- x ** 2 / 2 )
plt.plot(x, y)
